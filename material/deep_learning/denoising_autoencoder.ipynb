# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# copy from https://blog.naver.com/ckdgus1433/221443838135

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# MNIST 로딩 (라벨은 필요없기 때문에 버림)
(x_train, _), (x_test, _) = mnist.load_data()

# 데이터 정규화 및 Reshape
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 784))
x_test = np.reshape(x_test, (len(x_test), 784))

# 원본데이터에 Noise 추가
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Noise가 추가된 데이터 확인
n = 10
plt.figure(figsize=(20, 2))
for i in range(1,n):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# 모형 구성
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=784))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(784, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy')

# 모형 학습
model.fit(x_train_noisy, x_train, 
          nb_epoch=100,
          batch_size=256,
          shuffle=True,
          validation_data=(x_test_noisy, x_test))

# 결과 확인
decoded_imgs = model.predict(x_test_noisy)
n = 10
plt.figure(figsize=(20, 6))
for i in range(1, n):
    # display original
    ax = plt.subplot(3, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display noisy
    ax = plt.subplot(3, n, i + n)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(3, n, i + 2*n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.2670 - val_loss: 0.2062
# Epoch 2/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1888 - val_loss: 0.1727
# Epoch 3/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1650 - val_loss: 0.1574
# Epoch 4/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1548 - val_loss: 0.1503
# Epoch 5/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1484 - val_loss: 0.1451
# Epoch 6/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1441 - val_loss: 0.1417
# Epoch 7/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1410 - val_loss: 0.1387
# Epoch 8/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1384 - val_loss: 0.1366
# Epoch 9/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1364 - val_loss: 0.1351
# Epoch 10/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1344 - val_loss: 0.1330
# Epoch 11/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1326 - val_loss: 0.1316
# Epoch 12/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1309 - val_loss: 0.1299
# Epoch 13/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1294 - val_loss: 0.1291
# Epoch 14/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1282 - val_loss: 0.1278
# Epoch 15/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1270 - val_loss: 0.1273
# Epoch 16/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1260 - val_loss: 0.1271
# Epoch 17/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1252 - val_loss: 0.1253
# Epoch 18/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1245 - val_loss: 0.1244
# Epoch 19/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1237 - val_loss: 0.1242
# Epoch 20/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1230 - val_loss: 0.1235
# Epoch 21/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1225 - val_loss: 0.1229
# Epoch 22/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1220 - val_loss: 0.1232
# Epoch 23/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1216 - val_loss: 0.1223
# Epoch 24/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1210 - val_loss: 0.1217
# Epoch 25/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1206 - val_loss: 0.1219
# Epoch 26/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1202 - val_loss: 0.1211
# Epoch 27/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1197 - val_loss: 0.1206
# Epoch 28/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.1193 - val_loss: 0.1203
# Epoch 29/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1189 - val_loss: 0.1200
# Epoch 30/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1187 - val_loss: 0.1195
# Epoch 31/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1183 - val_loss: 0.1194
# Epoch 32/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.1179 - val_loss: 0.1195
# Epoch 33/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1178 - val_loss: 0.1188
# Epoch 34/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1174 - val_loss: 0.1191
# Epoch 35/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1171 - val_loss: 0.1196
# Epoch 36/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1170 - val_loss: 0.1183
# Epoch 37/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1168 - val_loss: 0.1182
# Epoch 38/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1166 - val_loss: 0.1186
# Epoch 39/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1164 - val_loss: 0.1177
# Epoch 40/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.1161 - val_loss: 0.1176
# Epoch 41/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1158 - val_loss: 0.1173
# Epoch 42/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1156 - val_loss: 0.1174
# Epoch 43/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1154 - val_loss: 0.1168
# Epoch 44/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1151 - val_loss: 0.1167
# Epoch 45/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1150 - val_loss: 0.1168
# Epoch 46/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1148 - val_loss: 0.1167
# Epoch 47/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1146 - val_loss: 0.1162
# Epoch 48/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1144 - val_loss: 0.1163
# Epoch 49/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1141 - val_loss: 0.1161
# Epoch 50/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1140 - val_loss: 0.1157
# Epoch 51/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1138 - val_loss: 0.1161
# Epoch 52/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1136 - val_loss: 0.1154
# Epoch 53/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1135 - val_loss: 0.1155
# Epoch 54/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1134 - val_loss: 0.1154
# Epoch 55/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1131 - val_loss: 0.1158
# Epoch 56/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1130 - val_loss: 0.1153
# Epoch 57/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1129 - val_loss: 0.1158
# Epoch 58/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1127 - val_loss: 0.1151
# Epoch 59/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1126 - val_loss: 0.1154
# Epoch 60/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1125 - val_loss: 0.1149
# Epoch 61/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1124 - val_loss: 0.1146
# Epoch 62/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1123 - val_loss: 0.1146
# Epoch 63/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1121 - val_loss: 0.1146
# Epoch 64/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1121 - val_loss: 0.1147
# Epoch 65/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1120 - val_loss: 0.1147
# Epoch 66/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1118 - val_loss: 0.1146
# Epoch 67/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1117 - val_loss: 0.1146
# Epoch 68/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1118 - val_loss: 0.1144
# Epoch 69/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1116 - val_loss: 0.1140
# Epoch 70/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1116 - val_loss: 0.1142
# Epoch 71/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1115 - val_loss: 0.1146
# Epoch 72/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1114 - val_loss: 0.1139
# Epoch 73/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1112 - val_loss: 0.1145
# Epoch 74/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1112 - val_loss: 0.1140
# Epoch 75/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1111 - val_loss: 0.1139
# Epoch 76/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1111 - val_loss: 0.1139
# Epoch 77/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1110 - val_loss: 0.1138
# Epoch 78/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.1109 - val_loss: 0.1141
# Epoch 79/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1109 - val_loss: 0.1138
# Epoch 80/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1108 - val_loss: 0.1140
# Epoch 81/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1108 - val_loss: 0.1135
# Epoch 82/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1107 - val_loss: 0.1135
# Epoch 83/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1107 - val_loss: 0.1138
# Epoch 84/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1106 - val_loss: 0.1133
# Epoch 85/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1105 - val_loss: 0.1138
# Epoch 86/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1106 - val_loss: 0.1131
# Epoch 87/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1104 - val_loss: 0.1132
# Epoch 88/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1104 - val_loss: 0.1136
# Epoch 89/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1104 - val_loss: 0.1135
# Epoch 90/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1103 - val_loss: 0.1134
# Epoch 91/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1102 - val_loss: 0.1132
# Epoch 92/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1102 - val_loss: 0.1137
# Epoch 93/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1101 - val_loss: 0.1135
# Epoch 94/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1101 - val_loss: 0.1130
# Epoch 95/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1100 - val_loss: 0.1131
# Epoch 96/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1100 - val_loss: 0.1131
# Epoch 97/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1099 - val_loss: 0.1143
# Epoch 98/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1099 - val_loss: 0.1130
# Epoch 99/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1099 - val_loss: 0.1127
# Epoch 100/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1098 - val_loss: 0.1134
