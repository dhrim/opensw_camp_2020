# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# # YOLO 학습
#
# YOLO에 대한 커스텀 데이터 학습
#
# https://github.com/qqwweee/keras-yolo3

# %%
# %%shell
# pip uninstall -y keras
# pip install keras==2.2.4
# Out:
# Uninstalling Keras-2.3.1:
#   Successfully uninstalled Keras-2.3.1
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#      |████████████████████████████████| 317kB 4.7MB/s
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Installing collected packages: keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.2.4

# %% [markdown]
# ## 프로젝트 다운로드

# %%
# %cd /content

# !rm -rf keras-yolo3

# !git clone https://github.com/qqwweee/keras-yolo3
# Out:
# /content
# Cloning into 'keras-yolo3'...
# remote: Enumerating objects: 144, done.
# remote: Total 144 (delta 0), reused 0 (delta 0), pack-reused 144
# Receiving objects: 100% (144/144), 151.08 KiB | 1.25 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %% [markdown]
# ## YOLO3 모델 다운로드

# %%
# %cd /content/keras-yolo3
# !wget wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# /content/keras-yolo3
# --2020-08-25 00:08:32--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2020-08-25 00:08:32--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  1.39MB/s    in 3m 4s
#
# 2020-08-25 00:11:36 (1.29 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# FINISHED --2020-08-25 00:11:36--
# Total wall clock time: 3m 5s
# Downloaded: 1 files, 237M in 3m 4s (1.29 MB/s)

# %% [markdown]
# ## 모델 파일 변환
#
# DarkNet의 모델파일을 Keras에서 사용할 수 있는 모델 파일로 변환한다.
#
#
# - convert.py : 변환 실행 파일
# - yolov3.cfg : Darknet에서 사용하는 모델 구조 정의 파일
# - yolov3.weight : Darknet으로 학습된 모델 파일
#
# 실행 결과로 다음의 h5 파일로 변환된다.
# - yolov3.h5 : 변환된 모델 파일

# %%
# !head -40 yolov3.cfg
# Out:
# [net]
# # Testing
# batch=1
# subdivisions=1
# # Training
# # batch=64
# # subdivisions=16
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1

# %%
# 실행하기전 기존것이 있다면 삭제
# !rm -rf yolov3.h5

# 실행 
# %run convert.py yolov3.cfg yolov3.weights yolov3.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Parsing section convolutional_1
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section convolutional_2
# conv2d bn leaky (1, 1, 64, 32)
# Parsing section convolutional_3
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section shortcut_0
# Parsing section convolutional_4
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section convolutional_5
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_6
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_1
# Parsing section convolutional_7
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_8
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_2
# Parsing section convolutional_9
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_10
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_11
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_3
# Parsing section convolutional_12
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_13
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_4
# Parsing section convolutional_14
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_15
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_5
# Parsing section convolutional_16
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_17
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_6
# Parsing section convolutional_18
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_19
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_7
# Parsing section convolutional_20
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_21
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_8
# Parsing section convolutional_22
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_23
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_9
# Parsing section convolutional_24
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_25
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_10
# Parsing section convolutional_26
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_27
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_28
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_11
# Parsing section convolutional_29
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_30
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_12
# Parsing section convolutional_31
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_32
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_13
# Parsing section convolutional_33
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_34
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_14
# Parsing section convolutional_35
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_36
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_15
# Parsing section convolutional_37
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_38
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_16
# Parsing section convolutional_39
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_40
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_17
# Parsing section convolutional_41
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_42
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_18
# Parsing section convolutional_43
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_44
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_45
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_19
# Parsing section convolutional_46
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_47
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_20
# Parsing section convolutional_48
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_49
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_21
# Parsing section convolutional_50
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_51
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_22
# Parsing section convolutional_52
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_53
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_54
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_55
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_56
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_57
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_58
# conv2d    linear (1, 1, 1024, 255)
# Parsing section yolo_0
# Parsing section route_0
# Parsing section convolutional_59
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section upsample_0
# Parsing section route_1
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_1/ResizeNearestNeighbor:0' shape=(?, ?, ?, 256) dtype=float32>, <tf.Tensor 'add_19/add:0' shape=(?, ?, ?, 512) dtype=float32>]
# Parsing section convolutional_60
# conv2d bn leaky (1, 1, 768, 256)
# Parsing section convolutional_61
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_62
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_63
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_64
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_65
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_66
# conv2d    linear (1, 1, 512, 255)
# Parsing section yolo_1
# Parsing section route_2
# Parsing section convolutional_67
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section upsample_1
# Parsing section route_3
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_2/ResizeNearestNeighbor:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'add_11/add:0' shape=(?, ?, ?, 256) dtype=float32>]
# Parsing section convolutional_68
# conv2d bn leaky (1, 1, 384, 128)
# Parsing section convolutional_69
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_70
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_71
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_72
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_73
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_74
# conv2d    linear (1, 1, 256, 255)
# Parsing section yolo_2
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 18432       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 3 2048        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 3 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 6 18432       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 6 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 6 0           leaky_re_lu_2[0][0]
#                                                                  leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 6 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 73728       zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 1 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 6 8192        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 6 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 73728       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 1 512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 1 0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 8192        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 73728       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 1 512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 1 0           add_2[0][0]
#                                                                  leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, None, None, 1 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 2 294912      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 2 1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 1 512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 2 1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 2 0           leaky_re_lu_10[0][0]
#                                                                  leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 1 32768       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 1 512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 2 1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 2 0           add_4[0][0]
#                                                                  leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 1 32768       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 1 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 2 1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 2 0           add_5[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 32768       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 1 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 2 1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 2 0           add_6[0][0]
#                                                                  leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 1 32768       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 1 512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 2 1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 2 0           add_7[0][0]
#                                                                  leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 1 32768       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 1 512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 2 1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 2 0           add_8[0][0]
#                                                                  leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 1 32768       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 1 512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 2 1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 2 0           add_9[0][0]
#                                                                  leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 1 32768       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 1 512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 2 1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 2 0           add_10[0][0]
#                                                                  leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, None, None, 2 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 5 1179648     zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 5 2048        conv2d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 2 1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 5 2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 5 0           leaky_re_lu_27[0][0]
#                                                                  leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 2 131072      add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 2 1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 5 2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 5 0           add_12[0][0]
#                                                                  leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 2 131072      add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 2 1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 5 2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, None, 5 0           add_13[0][0]
#                                                                  leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 2 131072      add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 2 1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 5 2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, None, None, 5 0           add_14[0][0]
#                                                                  leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 2 131072      add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 2 1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 5 2048        conv2d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, None, 5 0           add_15[0][0]
#                                                                  leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 2 131072      add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 2 1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 5 2048        conv2d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 5 0           add_16[0][0]
#                                                                  leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 2 131072      add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 2 1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 5 2048        conv2d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 5 0           add_17[0][0]
#                                                                  leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 2 131072      add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 2 1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 5 2048        conv2d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 5 0           add_18[0][0]
#                                                                  leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, None, None, 5 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 4718592     zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 4096        conv2d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 5 2048        conv2d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 1 4096        conv2d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 1 0           leaky_re_lu_44[0][0]
#                                                                  leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 5 524288      add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 5 2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 1 4096        conv2d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 1 0           add_20[0][0]
#                                                                  leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 5 524288      add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 5 2048        conv2d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 1 4096        conv2d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 1 0           add_21[0][0]
#                                                                  leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 5 524288      add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 5 2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 1 4096        conv2d_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 1 0           add_22[0][0]
#                                                                  leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 5 524288      add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 5 2048        conv2d_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 1 4096        conv2d_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 5 2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 1 4096        conv2d_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 5 2048        conv2d_57[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 2 1024        conv2d_60[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, None, None, 2 0           leaky_re_lu_59[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 7 0           up_sampling2d_1[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 2 196608      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 2 1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 5 2048        conv2d_62[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 2 1024        conv2d_63[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 5 2048        conv2d_64[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 2 1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, None, None, 1 512         conv2d_68[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 1 0           leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 3 0           up_sampling2d_2[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 1 49152       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, None, None, 1 512         conv2d_69[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, None, None, 2 1024        conv2d_70[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, None, None, 1 512         conv2d_71[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, None, None, 2 1024        conv2d_72[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, None, None, 1 512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 1 4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 5 2048        conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, None, None, 2 1024        conv2d_74[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 2 261375      leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 2 130815      leaky_re_lu_65[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 2 65535       leaky_re_lu_72[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# None
# Saved Keras model to yolov3.h5
# Read 62001757 of 62001757.0 from Darknet weights.

# %%
# !ls -al
# Out:
# total 485192
# drwxr-xr-x 6 root root      4096 Aug 25 00:13 .
# drwxr-xr-x 1 root root      4096 Aug 25 00:08 ..
# -rw-r--r-- 1 root root      1323 Aug 25 00:08 coco_annotation.py
# -rw-r--r-- 1 root root     10093 Aug 25 00:08 convert.py
# -rw-r--r-- 1 root root      5707 Aug 25 00:08 darknet53.cfg
# drwxr-xr-x 2 root root      4096 Aug 25 00:08 font
# drwxr-xr-x 8 root root      4096 Aug 25 00:08 .git
# -rw-r--r-- 1 root root      1201 Aug 25 00:08 .gitignore
# -rw-r--r-- 1 root root      3482 Aug 25 00:08 kmeans.py
# -rw-r--r-- 1 root root      1064 Aug 25 00:08 LICENSE
# drwxr-xr-x 2 root root      4096 Aug 25 00:08 model_data
# -rw-r--r-- 1 root root      4077 Aug 25 00:08 README.md
# -rw-r--r-- 1 root root     10686 Aug 25 00:08 train_bottleneck.py
# -rw-r--r-- 1 root root      8332 Aug 25 00:08 train.py
# -rw-r--r-- 1 root root      1416 Aug 25 00:08 voc_annotation.py
# drwxr-xr-x 2 root root      4096 Aug 25 00:08 yolo3
# -rw-r--r-- 1 root root      8540 Aug 25 00:08 yolo.py
# -rw-r--r-- 1 root root      8342 Aug 25 00:08 yolov3.cfg
# -rw-r--r-- 1 root root 248691704 Aug 25 00:13 yolov3.h5
# -rw-r--r-- 1 root root      1915 Aug 25 00:08 yolov3-tiny.cfg
# -rw-r--r-- 1 root root 248007048 Mar 25  2018 yolov3.weights
# -rw-r--r-- 1 root root      2304 Aug 25 00:08 yolo_video.py

# %% [markdown]
# # 커스텀 데이터 학습

# %% [markdown]
# ## 데이터 파일 다운로드

# %%
# %cd /content/keras-yolo3
# !wget https://github.com/dhrim/opensw_camp_2020/raw/master/material/deep_learning/dogs_cats_yolo_labeled.zip
# Out:
# /content/keras-yolo3
# --2020-08-26 00:06:42--  https://github.com/dhrim/opensw_camp_2020/raw/master/material/deep_learning/dogs_cats_yolo_labeled.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dhrim/opensw_camp_2020/master/material/deep_learning/dogs_cats_yolo_labeled.zip [following]
# --2020-08-26 00:06:43--  https://raw.githubusercontent.com/dhrim/opensw_camp_2020/master/material/deep_learning/dogs_cats_yolo_labeled.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5478153 (5.2M) [application/zip]
# Saving to: ‘dogs_cats_yolo_labeled.zip’
#
# dogs_cats_yolo_labe 100%[===================>]   5.22M  32.2MB/s    in 0.2s
#
# 2020-08-26 00:06:43 (32.2 MB/s) - ‘dogs_cats_yolo_labeled.zip’ saved [5478153/5478153]

# %%
# !unzip dogs_cats_yolo_labeled.zip
# Out:
# Archive:  dogs_cats_yolo_labeled.zip
#    creating: dogs_cats_yolo_labeled/
#   inflating: dogs_cats_yolo_labeled/cat.99.jpg
#   inflating: dogs_cats_yolo_labeled/cat.99.xml
#   inflating: dogs_cats_yolo_labeled/cat.990.jpg
#   inflating: dogs_cats_yolo_labeled/cat.990.xml
#   inflating: dogs_cats_yolo_labeled/cat.9900.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9900.xml
#   inflating: dogs_cats_yolo_labeled/cat.9901.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9901.xml
#   inflating: dogs_cats_yolo_labeled/cat.9902.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9902.xml
#   inflating: dogs_cats_yolo_labeled/cat.9903.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9903.xml
#   inflating: dogs_cats_yolo_labeled/cat.9904.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9904.xml
#   inflating: dogs_cats_yolo_labeled/cat.9905.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9905.xml
#   inflating: dogs_cats_yolo_labeled/cat.9906.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9906.xml
#   inflating: dogs_cats_yolo_labeled/cat.9907.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9907.xml
#   inflating: dogs_cats_yolo_labeled/cat.9908.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9908.xml
#   inflating: dogs_cats_yolo_labeled/cat.9909.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9909.xml
#   inflating: dogs_cats_yolo_labeled/cat.991.jpg
#   inflating: dogs_cats_yolo_labeled/cat.991.xml
#   inflating: dogs_cats_yolo_labeled/cat.9910.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9910.xml
#   inflating: dogs_cats_yolo_labeled/cat.9911.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9911.xml
#   inflating: dogs_cats_yolo_labeled/cat.9912.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9912.xml
#   inflating: dogs_cats_yolo_labeled/cat.9913.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9913.xml
#   inflating: dogs_cats_yolo_labeled/cat.9914.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9914.xml
#   inflating: dogs_cats_yolo_labeled/cat.9915.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9915.xml
#   inflating: dogs_cats_yolo_labeled/cat.9916.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9916.xml
#   inflating: dogs_cats_yolo_labeled/cat.9917.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9917.xml
#   inflating: dogs_cats_yolo_labeled/cat.9918.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9918.xml
#   inflating: dogs_cats_yolo_labeled/cat.9919.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9919.xml
#   inflating: dogs_cats_yolo_labeled/cat.992.jpg
#   inflating: dogs_cats_yolo_labeled/cat.992.xml
#   inflating: dogs_cats_yolo_labeled/cat.9920.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9920.xml
#   inflating: dogs_cats_yolo_labeled/cat.9921.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9921.xml
#   inflating: dogs_cats_yolo_labeled/cat.9922.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9922.xml
#   inflating: dogs_cats_yolo_labeled/cat.9923.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9923.xml
#   inflating: dogs_cats_yolo_labeled/cat.9924.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9924.xml
#   inflating: dogs_cats_yolo_labeled/cat.9925.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9925.xml
#   inflating: dogs_cats_yolo_labeled/cat.9926.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9926.xml
#   inflating: dogs_cats_yolo_labeled/cat.9927.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9927.xml
#   inflating: dogs_cats_yolo_labeled/cat.9928.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9928.xml
#   inflating: dogs_cats_yolo_labeled/cat.9929.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9929.xml
#   inflating: dogs_cats_yolo_labeled/cat.993.jpg
#   inflating: dogs_cats_yolo_labeled/cat.993.xml
#   inflating: dogs_cats_yolo_labeled/cat.9930.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9930.xml
#   inflating: dogs_cats_yolo_labeled/cat.9931.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9931.xml
#   inflating: dogs_cats_yolo_labeled/cat.9932.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9932.xml
#   inflating: dogs_cats_yolo_labeled/cat.9933.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9933.xml
#   inflating: dogs_cats_yolo_labeled/cat.9934.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9934.xml
#   inflating: dogs_cats_yolo_labeled/cat.9935.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9935.xml
#   inflating: dogs_cats_yolo_labeled/cat.9936.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9936.xml
#   inflating: dogs_cats_yolo_labeled/cat.9937.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9937.xml
#   inflating: dogs_cats_yolo_labeled/cat.9938.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9938.xml
#   inflating: dogs_cats_yolo_labeled/cat.9939.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9939.xml
#   inflating: dogs_cats_yolo_labeled/cat.994.jpg
#   inflating: dogs_cats_yolo_labeled/cat.994.xml
#   inflating: dogs_cats_yolo_labeled/cat.9940.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9940.xml
#   inflating: dogs_cats_yolo_labeled/cat.9941.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9941.xml
#   inflating: dogs_cats_yolo_labeled/cat.9942.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9942.xml
#   inflating: dogs_cats_yolo_labeled/cat.9943.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9943.xml
#   inflating: dogs_cats_yolo_labeled/cat.9944.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9944.xml
#   inflating: dogs_cats_yolo_labeled/cat.9945.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9945.xml
#   inflating: dogs_cats_yolo_labeled/cat.9946.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9946.xml
#   inflating: dogs_cats_yolo_labeled/cat.9947.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9947.xml
#   inflating: dogs_cats_yolo_labeled/cat.9948.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9948.xml
#   inflating: dogs_cats_yolo_labeled/cat.9949.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9949.xml
#   inflating: dogs_cats_yolo_labeled/cat.995.jpg
#   inflating: dogs_cats_yolo_labeled/cat.995.xml
#   inflating: dogs_cats_yolo_labeled/cat.9950.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9950.xml
#   inflating: dogs_cats_yolo_labeled/cat.9951.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9951.xml
#   inflating: dogs_cats_yolo_labeled/cat.9952.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9952.xml
#   inflating: dogs_cats_yolo_labeled/cat.9953.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9953.xml
#   inflating: dogs_cats_yolo_labeled/cat.9954.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9954.xml
#   inflating: dogs_cats_yolo_labeled/cat.9955.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9955.xml
#   inflating: dogs_cats_yolo_labeled/cat.9956.jpg
#   inflating: dogs_cats_yolo_labeled/cat.
jpg
#   inflating: dogs_cats_yolo_labeled/cat.9994.xml
#   inflating: dogs_cats_yolo_labeled/cat.9995.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9995.xml
#   inflating: dogs_cats_yolo_labeled/cat.9996.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9996.xml
#   inflating: dogs_cats_yolo_labeled/cat.9997.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9997.xml
#   inflating: dogs_cats_yolo_labeled/cat.9998.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9998.xml
#   inflating: dogs_cats_yolo_labeled/cat.9999.jpg
#   inflating: dogs_cats_yolo_labeled/cat.9999.xml
#  extracting: dogs_cats_yolo_labeled/class_names.txt
#   inflating: dogs_cats_yolo_labeled/dog.99.jpg
#   inflating: dogs_cats_yolo_labeled/dog.99.xml
#   inflating: dogs_cats_yolo_labeled/dog.990.jpg
#   inflating: dogs_cats_yolo_labeled/dog.990.xml
#   inflating: dogs_cats_yolo_labeled/dog.9900.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9900.xml
#   inflating: dogs_cats_yolo_labeled/dog.9901.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9901.xml
#   inflating: dogs_cats_yolo_labeled/dog.9902.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9902.xml
#   inflating: dogs_cats_yolo_labeled/dog.9903.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9903.xml
#   inflating: dogs_cats_yolo_labeled/dog.9904.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9904.xml
#   inflating: dogs_cats_yolo_labeled/dog.9905.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9905.xml
#   inflating: dogs_cats_yolo_labeled/dog.9906.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9906.xml
#   inflating: dogs_cats_yolo_labeled/dog.9907.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9907.xml
#   inflating: dogs_cats_yolo_labeled/dog.9908.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9908.xml
#   inflating: dogs_cats_yolo_labeled/dog.9909.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9909.xml
#   inflating: dogs_cats_yolo_labeled/dog.991.jpg
#   inflating: dogs_cats_yolo_labeled/dog.991.xml
#   inflating: dogs_cats_yolo_labeled/dog.9910.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9910.xml
#   inflating: dogs_cats_yolo_labeled/dog.9911.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9911.xml
#   inflating: dogs_cats_yolo_labeled/dog.9912.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9912.xml
#   inflating: dogs_cats_yolo_labeled/dog.9913.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9913.xml
#   inflating: dogs_cats_yolo_labeled/dog.9914.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9914.xml
#   inflating: dogs_cats_yolo_labeled/dog.9915.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9915.xml
#   inflating: dogs_cats_yolo_labeled/dog.9916.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9916.xml
#   inflating: dogs_cats_yolo_labeled/dog.9917.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9917.xml
#   inflating: dogs_cats_yolo_labeled/dog.9918.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9918.xml
#   inflating: dogs_cats_yolo_labeled/dog.9919.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9919.xml
#   inflating: dogs_cats_yolo_labeled/dog.992.jpg
#   inflating: dogs_cats_yolo_labeled/dog.992.xml
#   inflating: dogs_cats_yolo_labeled/dog.9920.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9920.xml
#   inflating: dogs_cats_yolo_labeled/dog.9921.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9921.xml
#   inflating: dogs_cats_yolo_labeled/dog.9922.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9922.xml
#   inflating: dogs_cats_yolo_labeled/dog.9923.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9923.xml
#   inflating: dogs_cats_yolo_labeled/dog.9924.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9924.xml
#   inflating: dogs_cats_yolo_labeled/dog.9925.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9925.xml
#   inflating: dogs_cats_yolo_labeled/dog.9926.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9926.xml
#   inflating: dogs_cats_yolo_labeled/dog.9927.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9927.xml
#   inflating: dogs_cats_yolo_labeled/dog.9928.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9928.xml
#   inflating: dogs_cats_yolo_labeled/dog.9929.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9929.xml
#   inflating: dogs_cats_yolo_labeled/dog.993.jpg
#   inflating: dogs_cats_yolo_labeled/dog.993.xml
#   inflating: dogs_cats_yolo_labeled/dog.9930.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9930.xml
#   inflating: dogs_cats_yolo_labeled/dog.9931.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9931.xml
#   inflating: dogs_cats_yolo_labeled/dog.9932.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9932.xml
#   inflating: dogs_cats_yolo_labeled/dog.9933.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9933.xml
#   inflating: dogs_cats_yolo_labeled/dog.9934.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9934.xml
#   inflating: dogs_cats_yolo_labeled/dog.9935.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9935.xml
#   inflating: dogs_cats_yolo_labeled/dog.9936.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9936.xml
#   inflating: dogs_cats_yolo_labeled/dog.9937.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9937.xml
#   inflating: dogs_cats_yolo_labeled/dog.9938.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9938.xml
#   inflating: dogs_cats_yolo_labeled/dog.9939.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9939.xml
#   inflating: dogs_cats_yolo_labeled/dog.994.jpg
#   inflating: dogs_cats_yolo_labeled/dog.994.xml
#   inflating: dogs_cats_yolo_labeled/dog.9940.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9940.xml
#   inflating: dogs_cats_yolo_labeled/dog.9941.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9941.xml
#   inflating: dogs_cats_yolo_labeled/dog.9942.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9942.xml
#   inflating: dogs_cats_yolo_labeled/dog.9943.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9943.xml
#   inflating: dogs_cats_yolo_labeled/dog.9944.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9944.xml
#   inflating: dogs_cats_yolo_labeled/dog.9945.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9945.xml
#   inflating: dogs_cats_yolo_labeled/dog.9946.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9946.xml
#   inflating: dogs_cats_yolo_labeled/dog.9947.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9947.xml
#   inflating: dogs_cats_yolo_labeled/dog.9948.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9948.xml
#   inflating: dogs_cats_yolo_labeled/dog.9949.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9949.xml
#   inflating: dogs_cats_yolo_labeled/dog.995.jpg
#   inflating: dogs_cats_yolo_labeled/dog.995.xml
#   inflating: dogs_cats_yolo_labeled/dog.9950.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9950.xml
#   inflating: dogs_cats_yolo_labeled/dog.9951.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9951.xml
#   inflating: dogs_cats_yolo_labeled/dog.9952.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9952.xml
#   inflating: dogs_cats_yolo_labeled/dog.9953.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9953.xml
#   inflating: dogs_cats_yolo_labeled/dog.9954.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9954.xml
#   inflating: dogs_cats_yolo_labeled/dog.9955.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9955.xml
#   inflating: dogs_cats_yolo_labeled/dog.9956.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9956.xml
#   inflating: dogs_cats_yolo_labeled/dog.9957.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9957.xml
#   inflating: dogs_cats_yolo_labeled/dog.9958.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9958.xml
#   inflating: dogs_cats_yolo_labeled/dog.9959.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9959.xml
#   inflating: dogs_cats_yolo_labeled/dog.996.jpg
#   inflating: dogs_cats_yolo_labeled/dog.996.xml
#   inflating: dogs_cats_yolo_labeled/dog.9960.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9960.xml
#   inflating: dogs_cats_yolo_labeled/dog.9961.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9961.xml
#   inflating: dogs_cats_yolo_labeled/dog.9962.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9962.xml
#   inflating: dogs_cats_yolo_labeled/dog.9963.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9963.xml
#   inflating: dogs_cats_yolo_labeled/dog.9964.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9964.xml
#   inflating: dogs_cats_yolo_labeled/dog.9965.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9965.xml
#   inflating: dogs_cats_yolo_labeled/dog.9966.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9966.xml
#   inflating: dogs_cats_yolo_labeled/dog.9967.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9967.xml
#   inflating: dogs_cats_yolo_labeled/dog.9968.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9968.xml
#   inflating: dogs_cats_yolo_labeled/dog.9969.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9969.xml
#   inflating: dogs_cats_yolo_labeled/dog.997.jpg
#   inflating: dogs_cats_yolo_labeled/dog.997.xml
#   inflating: dogs_cats_yolo_labeled/dog.9970.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9970.xml
#   inflating: dogs_cats_yolo_labeled/dog.9971.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9971.xml
#   inflating: dogs_cats_yolo_labeled/dog.9972.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9972.xml
#   inflating: dogs_cats_yolo_labeled/dog.9973.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9973.xml
#   inflating: dogs_cats_yolo_labeled/dog.9974.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9974.xml
#   inflating: dogs_cats_yolo_labeled/dog.9975.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9975.xml
#   inflating: dogs_cats_yolo_labeled/dog.9976.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9976.xml
#   inflating: dogs_cats_yolo_labeled/dog.9977.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9977.xml
#   inflating: dogs_cats_yolo_labeled/dog.9978.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9978.xml
#   inflating: dogs_cats_yolo_labeled/dog.9979.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9979.xml
#   inflating: dogs_cats_yolo_labeled/dog.998.jpg
#   inflating: dogs_cats_yolo_labeled/dog.998.xml
#   inflating: dogs_cats_yolo_labeled/dog.9980.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9980.xml
#   inflating: dogs_cats_yolo_labeled/dog.9981.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9981.xml
#   inflating: dogs_cats_yolo_labeled/dog.9982.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9982.xml
#   inflating: dogs_cats_yolo_labeled/dog.9983.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9983.xml
#   inflating: dogs_cats_yolo_labeled/dog.9984.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9984.xml
#   inflating: dogs_cats_yolo_labeled/dog.9985.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9985.xml
#   inflating: dogs_cats_yolo_labeled/dog.9986.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9986.xml
#   inflating: dogs_cats_yolo_labeled/dog.9987.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9987.xml
#   inflating: dogs_cats_yolo_labeled/dog.9988.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9988.xml
#   inflating: dogs_cats_yolo_labeled/dog.9989.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9989.xml
#   inflating: dogs_cats_yolo_labeled/dog.999.jpg
#   inflating: dogs_cats_yolo_labeled/dog.999.xml
#   inflating: dogs_cats_yolo_labeled/dog.9990.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9990.xml
#   inflating: dogs_cats_yolo_labeled/dog.9991.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9991.xml
#   inflating: dogs_cats_yolo_labeled/dog.9992.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9992.xml
#   inflating: dogs_cats_yolo_labeled/dog.9993.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9993.xml
#   inflating: dogs_cats_yolo_labeled/dog.9994.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9994.xml
#   inflating: dogs_cats_yolo_labeled/dog.9995.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9995.xml
#   inflating: dogs_cats_yolo_labeled/dog.9996.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9996.xml
#   inflating: dogs_cats_yolo_labeled/dog.9997.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9997.xml
#   inflating: dogs_cats_yolo_labeled/dog.9998.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9998.xml
#   inflating: dogs_cats_yolo_labeled/dog.9999.jpg
#   inflating: dogs_cats_yolo_labeled/dog.9999.xml

# %% [markdown]
# ## 레이블링 데이터 포멧 변환
#
# dogs_cats_yolo_labeled 폴더 안의 xml 파일들을 읽어서 labels.txt 파일을 생성한다.

# %%
# %cd /content/keras-yolo3

import os
import glob

CLASS_NAMES = [ "cat", "dog" ] 
# TAGET_FOLDER_NAME = "labels"
TAGET_FOLDER_NAME = "dogs_cats_yolo_labeled"


label_file_names = []
for file_name in glob.glob(TAGET_FOLDER_NAME+'/*.xml'):
  label_file_names.append(file_name)

print(label_file_names)

import xml.etree.ElementTree as ET

all_record = []

for file_name in label_file_names:

  with open(file_name) as in_file:

    tree = ET.parse(in_file)
    root = tree.getroot()

    a_record = [ file_name.replace("xml", "jpg") ]

    for obj in root.iter('object'):
        difficult = obj.find('difficult').text
        cls = obj.find('name').text
        if cls not in CLASS_NAMES or int(difficult)==1:
            continue
        cls_id = str(CLASS_NAMES.index(cls))
        xmlbox = obj.find('bndbox')
        xmin = xmlbox.find('xmin').text
        ymin = xmlbox.find('ymin').text
        xmax = xmlbox.find('xmax').text
        ymax = xmlbox.find('ymax').text

        a_record.append(",".join([xmin,ymin,xmax,ymax,cls_id]))

    all_record.append(a_record)


with open("labels.txt", "w") as f:
  for a_record in all_record:
    print(a_record)
    f.write(" ".join([str(i) for i in a_record]))
    f.write("\n")

print("labels.txt created.")
# Out:
# /content/keras-yolo3
# ['dogs_cats_yolo_labeled/cat.9943.xml', 'dogs_cats_yolo_labeled/dog.9980.xml', 'dogs_cats_yolo_labeled/dog.9960.xml', 'dogs_cats_yolo_labeled/cat.9926.xml', 'dogs_cats_yolo_labeled/dog.9964.xml', 'dogs_cats_yolo_labeled/dog.9936.xml', 'dogs_cats_yolo_labeled/cat.9925.xml', 'dogs_cats_yolo_labeled/cat.9950.xml', 'dogs_cats_yolo_labeled/dog.9961.xml', 'dogs_cats_yolo_labeled/dog.9974.xml', 'dogs_cats_yolo_labeled/dog.9962.xml', 'dogs_cats_yolo_labeled/cat.999.xml', 'dogs_cats_yolo_labeled/dog.9956.xml', 'dogs_cats_yolo_labeled/dog.9910.xml', 'dogs_cats_yolo_labeled/dog.9919.xml', 'dogs_cats_yolo_labeled/dog.994.xml', 'dogs_cats_yolo_labeled/dog.9989.xml', 'dogs_cats_yolo_labeled/cat.994.xml', 'dogs_cats_yolo_labeled/cat.9929.xml', 'dogs_cats_yolo_labeled/cat.9918.xml', 'dogs_cats_yolo_labeled/dog.9990.xml', 'dogs_cats_yolo_labeled/cat.9942.xml', 'dogs_cats_yolo_labeled/dog.9903.xml', 'dogs_cats_yolo_labeled/dog.9957.xml', 'dogs_cats_yolo_labeled/cat.9905.xml', 'dogs_cats_yolo_labeled/dog.9926.xml', 'dogs_cats_yolo_labeled/dog.9921.xml', 'dogs_cats_yolo_labeled/cat.9976.xml', 'dogs_cats_yolo_labeled/cat.9977.xml', 'dogs_cats_yolo_labeled/cat.9914.xml', 'dogs_cats_yolo_labeled/cat.9916.xml', 'dogs_cats_yolo_labeled/dog.9997.xml', 'dogs_cats_yolo_labeled/dog.9954.xml', 'dogs_cats_yolo_labeled/cat.9934.xml', 'dogs_cats_yolo_labeled/cat.9928.xml', 'dogs_cats_yolo_labeled/cat.9957.xml', 'dogs_cats_yolo_labeled/cat.997.xml', 'dogs_cats_yolo_labeled/dog.9970.xml', 'dogs_cats_yolo_labeled/dog.995.xml', 'dogs_cats_yolo_labeled/cat.9933.xml', 'dogs_cats_yolo_labeled/cat.9901.xml', 'dogs_cats_yolo_labeled/cat.9974.xml', 'dogs_cats_yolo_labeled/dog.9985.xml', 'dogs_cats_yolo_labeled/cat.9911.xml', 'dogs_cats_yolo_labeled/dog.9933.xml', 'dogs_cats_yolo_labeled/dog.999.xml', 'dogs_cats_yolo_labeled/cat.9903.xml', 'dogs
# ['dogs_cats_yolo_labeled/cat.9926.jpg', '16,25,219,452,0']
# ['dogs_cats_yolo_labeled/dog.9964.jpg', '60,33,431,248,1']
# ['dogs_cats_yolo_labeled/dog.9936.jpg', '66,41,259,487,1']
# ['dogs_cats_yolo_labeled/cat.9925.jpg', '16,45,217,178,0']
# ['dogs_cats_yolo_labeled/cat.9950.jpg', '42,1,164,196,0']
# ['dogs_cats_yolo_labeled/dog.9961.jpg', '12,8,154,276,1']
# ['dogs_cats_yolo_labeled/dog.9974.jpg', '62,14,215,370,1']
# ['dogs_cats_yolo_labeled/dog.9962.jpg', '62,63,441,355,1']
# ['dogs_cats_yolo_labeled/cat.999.jpg', '35,12,240,284,0']
# ['dogs_cats_yolo_labeled/dog.9956.jpg', '20,13,231,160,1']
# ['dogs_cats_yolo_labeled/dog.9910.jpg', '145,70,381,233,1']
# ['dogs_cats_yolo_labeled/dog.9919.jpg', '4,67,349,387,1']
# ['dogs_cats_yolo_labeled/dog.994.jpg', '130,19,407,308,1']
# ['dogs_cats_yolo_labeled/dog.9989.jpg', '21,48,296,498,1']
# ['dogs_cats_yolo_labeled/cat.994.jpg', '112,117,262,362,0']
# ['dogs_cats_yolo_labeled/cat.9929.jpg', '70,57,245,321,0']
# ['dogs_cats_yolo_labeled/cat.9918.jpg', '156,32,410,352,0']
# ['dogs_cats_yolo_labeled/dog.9990.jpg', '6,14,434,487,1']
# ['dogs_cats_yolo_labeled/cat.9942.jpg', '108,34,366,410,0']
# ['dogs_cats_yolo_labeled/dog.9903.jpg', '22,33,354,468,1']
# ['dogs_cats_yolo_labeled/dog.9957.jpg', '28,9,390,462,1']
# ['dogs_cats_yolo_labeled/cat.9905.jpg', '43,5,367,448,0']
# ['dogs_cats_yolo_labeled/dog.9926.jpg', '41,11,452,458,1']
# ['dogs_cats_yolo_labeled/dog.9921.jpg', '3,9,261,437,1']
# ['dogs_cats_yolo_labeled/cat.9976.jpg', '28,23,294,193,0']
# ['dogs_cats_yolo_labeled/cat.9977.jpg', '29,15,266,411,0']
# ['dogs_cats_yolo_labeled/cat.9914.jpg', '32,37,234,494,0']
# ['dogs_cats_yolo_labeled/cat.9916.jpg', '27,5,180,351,0']
# ['dogs_cats_yolo_labeled/dog.9997.jpg', '46,77,415,344,1']
# ['dogs_cats_yolo_labeled/dog.9954.jpg', '13,15,254,264,1']
# ['dogs_cats_yolo_labeled/cat.9934.jpg', '50,2,337,417,0']
# ['dogs_cats_yolo_labeled/cat.9928.jpg', '55,6,205,430,0']
# ['dogs_cats_yolo_labeled/cat.9957.jpg', '27,7,493,333,0']
# ['dogs_cats_yolo_labeled/cat.997.jpg', '31,18,478,300,0']
# ['dogs_cats_yolo_labeled/dog.9970.jpg', '131,105,339,245,1']
# ['dogs_cats_yolo_labeled/dog.995.jpg', '179,30,447,356,1']
# ['dogs_cats_yolo_labeled/cat.9933.jpg', '59,4,388,330,0']
# ['dogs_cats_yolo_labeled/cat.9901.jpg', '30,40,285,273,0', '132,19,401,435,0']
# ['dogs_cats_yolo_labeled/cat.9974.jpg', '19,8,308,236,0']
# ['dogs_cats_yolo_labeled/dog.9985.jpg', '22,97,385,301,1']
# ['dogs_cats_yolo_labeled/cat.9911.jpg', '76,17,156,120,0', '156,67,250,232,0']
# ['dogs_cats_yolo_labeled/dog.9933.jpg', '37,23,242,392,1']
# ['dogs_cats_yolo_labeled/dog.999.jpg', '24,5,472,441,1']
# ['dogs_cats_yolo_labeled/cat.9903.jpg', '38,16,478,327,0']
# ['dogs_cats_yolo_labeled/cat.9944.jpg', '54,16,327,307,0']
# ['dogs_cats_yolo_labeled/cat.990.jpg', '43,58,381,374,0']
# ['dogs_cats_yolo_labeled/dog.9906.jpg', '36,15,277,251,1']
# ['dogs_cats_yolo_labeled/cat.9955.jpg', '8,32,457,303,0']
# ['dogs_cats_yolo_labeled/cat.9981.jpg', '30,2,299,493,0']
# ['dogs_cats_yolo_labeled/cat.9999.jpg', '74,9,341,497,0']
# ['dogs_cats_yolo_labeled/cat.995.jpg', '71,13,261,178,0']
# ['dogs_cats_yolo_labeled/dog.9972.jpg', '132,41,323,371,1']
# ['dogs_cats_yolo_labeled/cat.991.jpg', '164,63,371,371,0']
# ['dogs_cats_yolo_labeled/dog.9966.jpg', '15,18,309,349,1']
# ['dogs_cats_yolo_labeled/dog.9935.jpg', '12,18,232,396,1']
# ['dogs_cats_yolo_labeled/dog.9953.jpg', '118,119,483,371,1']
# ['dogs_cats_yolo_labeled/dog.99.jpg', '61,12,470,358,1']
# ['dogs_cats_yolo_labeled/dog.9946.jpg', '16,22,218,282,1']
# ['dogs_cats_yolo_labeled/cat.9941.jpg', '72,45,399,296,0']
# ['dogs_cats_yolo_labeled/cat.9973.jpg', '24,2,191,318,0']
# ['dogs_cats_yolo_labeled/dog.991.jpg', '52,38,357,312,1']
# ['dogs_cats_yolo_labeled/cat.9959.jpg', '28,47,452,338,0']
# ['dogs_cats_yolo_labeled/cat.9900.jpg', '33,2,305,498,0']
# ['dogs_cats_yolo_labeled/cat.9963.jpg', '10,37,357,248,0']
# ['dogs_cats_yolo_labeled/dog.9967.jpg', '43,16,269,462,1']
# ['dogs_cats_yolo_labeled/dog.9971.jpg', '24,2,301,237,1']
# ['dogs_cats_yolo_labeled/dog.997.jpg', '29,10,243,170,1']
# ['dogs_cats_yolo_labeled/dog.992.jpg', '79,32,248,219,1']
# ['dogs_cats_yolo_labeled/cat.9930.jpg', '17,11,198,358,0']
# ['dogs_cats_yolo_labeled/dog.9982.jpg', '91,75,294,497,1']
# ['dogs_cats_yolo_labeled/cat.9964.jpg', '3,29,427,487,0']
# ['dogs_cats_yolo_labeled/dog.9986.jpg', '84,49,409,348,1']
# ['dogs_cats_yolo_labeled/dog.9923.jpg', '20,1,343,377,1']
# ['dogs_cats_yolo_labeled/dog.9941.jpg', '128,40,375,449,1']
# ['dogs_cats_yolo_labeled/dog.9905.jpg', '57,76,442,317,1']
# ['dogs_cats_yolo_labeled/cat.9909.jpg', '19,14,174,265,0']
# ['dogs_cats_yolo_labeled/cat.9980.jpg', '10,23,445,444,0']
# ['dogs_cats_yolo_labeled/cat.9937.jpg', '34,37,474,352,0']
# ['dogs_cats_yolo_labeled/cat.9948.jpg', '31,35,371,470,0']
# ['dogs_cats_yolo_labeled/cat.9978.jpg', '19,18,139,130,0']
# ['dogs_cats_yolo_labeled/cat.9969.jpg', '1,3,475,327,0']
# ['dogs_cats_yolo_labeled/cat.9990.jpg', '26,21,367,398,0']
# ['dogs_cats_yolo_labeled/cat.9949.jpg', '159,35,342,363,0']
# ['dogs_cats_yolo_labeled/cat.9987.jpg', '152,67,262,318,0', '263,23,357,251,0']
# ['dogs_cats_yolo_labeled/cat.9923.jpg', '62,13,271,492,0']
# ['dogs_cats_yolo_labeled/dog.9937.jpg', '12,28,335,193,1']
# ['dogs_cats_yolo_labeled/dog.9976.jpg', '34,26,491,372,1']
# ['dogs_cats_yolo_labeled/dog.9996.jpg', '58,10,306,252,1']
# ['dogs_cats_yolo_labeled/cat.9965.jpg', '102,18,362,423,0']
# ['dogs_cats_yolo_labeled/cat.99.jpg', '11,13,202,166,0']
# ['dogs_cats_yolo_labeled/dog.9979.jpg', '37,10,482,377,1']
# ['dogs_cats_yolo_labeled/dog.9909.jpg', '29,67,390,309,1']
# ['dogs_cats_yolo_labeled/dog.9991.jpg', '97,82,396,315,1']
# ['dogs_cats_yolo_labeled/dog.9918.jpg', '4,1,339,315,1']
# ['dogs_cats_yolo_labeled/dog.9924.jpg', '93,22,480,372,1']
# ['dogs_cats_yolo_labeled/dog.9925.jpg', '78,67,229,288,1']
# ['dogs_cats_yolo_labeled/dog.9928.jpg', '183,13,453,250,1']
# ['dogs_cats_yolo_labeled/cat.9904.jpg', '46,2,430,293,0']
# ['dogs_cats_yolo_labeled/dog.998.jpg', '12,33,468,496,1']
# ['dogs_cats_yolo_labeled/dog.9940.jpg', '82,72,312,375,1']
# ['dogs_cats_yolo_labeled/cat.9993.jpg', '67,20,323,410,0']
# ['dogs_cats_yolo_labeled/cat.998.jpg', '64,47,356,480,0']
# ['dogs_cats_yolo_labeled/cat.9931.jpg', '92,5,458,403,0']
# ['dogs_cats_yolo_labeled/dog.9983.jpg', '34,13,396,458,1']
# ['dogs_cats_yolo_labeled/cat.9971.jpg', '276,112,466,353,0']
# ['dogs_cats_yolo_labeled/dog.9939.jpg', '62,105,406,327,1']
# ['dogs_cats_yolo_labeled/dog.990.jpg', '3,4,93,73,1']
# ['dogs_cats_yolo_labeled/cat.9953.jpg', '22,49,337,451,0']
# ['dogs_cats_yolo_labeled/cat.9982.jpg', '25,25,437,422,0']
# ['dogs_cats_yolo_labeled/cat.9924.jpg', '161,94,343,374,0']
# ['dogs_cats_yolo_labeled/cat.9940.jpg', '30,57,453,277,0']
# ['dogs_cats_yolo_labeled/dog.9920.jpg', '23,10,487,374,1']
# ['dogs_cats_yolo_labeled/dog.9944.jpg', '181,54,371,280,1']
# ['dogs_cats_yolo_labeled/cat.9975.jpg', '87,14,328,364,0']
# ['dogs_cats_yolo_labeled/dog.9963.jpg', '19,10,273,233,1']
# ['dogs_cats_yolo_labeled/cat.9960.jpg', '170,49,278,151,0', '106,57,171,151,0', '10,153,150,234,0']
# ['dogs_cats_yolo_labeled/cat.9938.jpg', '202,59,417,267,0']
# ['dogs_cats_yolo_labeled/cat.996.jpg', '63,24,365,231,0']
# ['dogs_cats_yolo_labeled/cat.9913.jpg', '12,23,480,230,0']
# ['dogs_cats_yolo_labeled/cat.9947.jpg', '65,3,209,185,0']
# ['dogs_cats_yolo_labeled/dog.9922.jpg', '18,53,266,488,1']
# ['dogs_cats_yolo_labeled/dog.9993.jpg', '22,13,289,324,1']
# ['dogs_cats_yolo_labeled/dog.9938.jpg', '4,79,287,340,1']
# ['dogs_cats_yolo_labeled/cat.9902.jpg', '4,39,424,364,0']
# ['dogs_cats_yolo_labeled/cat.9939.jpg', '153,26,351,368,0']
# ['dogs_cats_yolo_labeled/cat.9906.jpg', '27,18,473,357,0']
# ['dogs_cats_yolo_labeled/cat.9972.jpg', '26,19,409,233,0']
# ['dogs_cats_yolo_labeled/cat.9932.jpg', '24,55,402,291,0']
# ['dogs_cats_yolo_labeled/dog.9959.jpg', '60,22,472,419,1']
# ['dogs_cats_yolo_labeled/dog.9999.jpg', '3,7,89,147,1']
# ['dogs_cats_yolo_labeled/dog.9951.jpg', '107,55,455,366,1']
# ['dogs_cats_yolo_labeled/cat.9986.jpg', '65,31,236,169,0']
# ['dogs_cats_yolo_labeled/cat.9992.jpg', '100,9,332,310,0']
# ['dogs_cats_yolo_labeled/cat.9921.jpg', '75,3,366,323,0']
# ['dogs_cats_yolo_labeled/dog.9968.jpg', '60,53,249,460,1']
# ['dogs_cats_yolo_labeled/dog.9950.jpg', '117,31,408,475,1']
# ['dogs_cats_yolo_labeled/cat.9962.jpg', '169,137,298,351,0']
# ['dogs_cats_yolo_labeled/cat.9961.jpg', '25,9,291,249,0']
# ['dogs_cats_yolo_labeled/cat.9970.jpg', '62,86,341,280,0']
# ['dogs_cats_yolo_labeled/cat.9997.jpg', '89,2,338,213,0']
# ['dogs_cats_yolo_labeled/cat.9910.jpg', '105,3,481,295,0']
# ['dogs_cats_yolo_labeled/cat.9922.jpg', '2,3,370,315,0']
# ['dogs_cats_yolo_labeled/cat.9927.jpg', '10,1,119,173,0']
# ['dogs_cats_yolo_labeled/cat.9954.jpg', '34,17,201,487,0']
# ['dogs_cats_yolo_labeled/dog.9913.jpg', '56,25,309,499,1']
# ['dogs_cats_yolo_labeled/cat.9917.jpg', '17,20,436,497,0']
# ['dogs_cats_yolo_labeled/dog.9915.jpg', '8,15,472,475,1']
# ['dogs_cats_yolo_labeled/dog.9984.jpg', '4,20,279,215,1', '283,5,491,218,1']
# ['dogs_cats_yolo_labeled/dog.9934.jpg', '97,11,404,374,1']
# ['dogs_cats_yolo_labeled/cat.9979.jpg', '143,28,372,363,0']
# ['dogs_cats_yolo_labeled/dog.9992.jpg', '35,23,188,147,1', '115,12,228,64,1']
# ['dogs_cats_yolo_labeled/dog.9916.jpg', '154,8,484,358,1']
# ['dogs_cats_yolo_labeled/dog.9932.jpg', '167,102,425,282,1']
# ['dogs_cats_yolo_labeled/dog.9931.jpg', '201,194,257,282,1']
# ['dogs_cats_yolo_labeled/dog.9914.jpg', '61,80,422,303,1']
# ['dogs_cats_yolo_labeled/dog.9965.jpg', '48,26,435,291,1']
# ['dogs_cats_yolo_labeled/dog.9900.jpg', '134,20,448,364,1']
# ['dogs_cats_yolo_labeled/dog.9943.jpg', '61,74,278,397,1']
# ['dogs_cats_yolo_labeled/cat.9945.jpg', '55,1,158,127,0']
# ['dogs_cats_yolo_labeled/cat.9988.jpg', '58,2,490,352,0']
# ['dogs_cats_yolo_labeled/dog.9908.jpg', '79,107,398,457,1']
# ['dogs_cats_yolo_labeled/dog.9988.jpg', '160,24,271,275,1', '292,80,495,270,1', '278,1,410,56,1']
# ['dogs_cats_yolo_labeled/cat.993.jpg', '77,1,336,217,0']
# ['dogs_cats_yolo_labeled/dog.9930.jpg', '130,91,408,328,1']
# ['dogs_cats_yolo_labeled/dog.9987.jpg', '91,4,398,341,1']
# ['dogs_cats_yolo_labeled/dog.9998.jpg', '109,174,227,408,1']
# ['dogs_cats_yolo_labeled/dog.9981.jpg', '35,16,252,444,1']
# ['dogs_cats_yolo_labeled/cat.9966.jpg', '8,70,121,249,0', '121,75,231,272,0', '232,88,311,271,0', '312,100,400,273,0']
# ['dogs_cats_yolo_labeled/cat.9936.jpg', '16,4,101,81,0']
# ['dogs_cats_yolo_labeled/dog.9901.jpg', '13,10,463,440,1']
# ['dogs_cats_yolo_labeled/cat.9956.jpg', '73,59,425,273,0']
# ['dogs_cats_yolo_labeled/cat.9919.jpg', '47,29,457,388,0']
# ['dogs_cats_yolo_labeled/dog.9945.jpg', '32,74,465,402,1']
# ['dogs_cats_yolo_labeled/cat.9991.jpg', '27,30,397,423,0']
# ['dogs_cats_yolo_labeled/dog.9995.jpg', '11,22,213,197,1']
# ['dogs_cats_yolo_labeled/dog.9952.jpg', '70,18,471,279,1']
# ['dogs_cats_yolo_labeled/cat.9984.jpg', '83,20,220,288,0']
# ['dogs_cats_yolo_labeled/cat.9967.jpg', '1,1,85,99,0']
# ['dogs_cats_yolo_labeled/dog.9958.jpg', '83,173,272,410,1']
# ['dogs_cats_yolo_labeled/dog.996.jpg', '25,20,331,203,1']
# ['dogs_cats_yolo_labeled/cat.9946.jpg', '88,29,299,257,0']
# ['dogs_cats_yolo_labeled/cat.9951.jpg', '5,3,324,228,0']
# ['dogs_cats_yolo_labeled/cat.9996.jpg', '47,2,367,418,0']
# ['dogs_cats_yolo_labeled/cat.9995.jpg', '50,3,345,180,0']
# ['dogs_cats_yolo_labeled/dog.9904.jpg', '54,75,435,307,1']
# ['dogs_cats_yolo_labeled/dog.9955.jpg', '140,17,443,339,1']
# ['dogs_cats_yolo_labeled/cat.9920.jpg', '171,2,393,275,0']
# ['dogs_cats_yolo_labeled/cat.9912.jpg', '85,51,344,289,0']
# ['dogs_cats_yolo_labeled/cat.9989.jpg', '25,35,488,480,0']
# ['dogs_cats_yolo_labeled/dog.9917.jpg', '19,19,325,353,1']
# ['dogs_cats_yolo_labeled/dog.9973.jpg', '52,37,277,424,1']
# ['dogs_cats_yolo_labeled/cat.9998.jpg', '35,12,256,208,0']
# ['dogs_cats_yolo_labeled/dog.9949.jpg', '32,36,233,344,1']
# ['dogs_cats_yolo_labeled/dog.9978.jpg', '14,20,394,264,1']
# ['dogs_cats_yolo_labeled/dog.9927.jpg', '39,39,341,306,1']
# ['dogs_cats_yolo_labeled/cat.9958.jpg', '52,79,392,476,0']
# ['dogs_cats_yolo_labeled/dog.9907.jpg', '6,40,422,286,1']
# ['dogs_cats_yolo_labeled/dog.9977.jpg', '158,8,365,344,1']
# ['dogs_cats_yolo_labeled/cat.9908.jpg', '8,9,280,493,0']
# ['dogs_cats_yolo_labeled/cat.9907.jpg', '115,13,397,409,0']
# ['dogs_cats_yolo_labeled/dog.9975.jpg', '9,40,301,435,1']
# ['dogs_cats_yolo_labeled/dog.9948.jpg', '29,25,469,323,1']
# ['dogs_cats_yolo_labeled/dog.9911.jpg', '187,11,453,330,1']
# ['dogs_cats_yolo_labeled/dog.9947.jpg', '301,1,482,132,1', '256,133,471,352,1', '29,57,257,357,1']
# ['dogs_cats_yolo_labeled/dog.9969.jpg', '70,5,230,282,1']
# ['dogs_cats_yolo_labeled/cat.992.jpg', '99,57,355,461,0']
# ['dogs_cats_yolo_labeled/dog.993.jpg', '115,74,344,331,1']
# ['dogs_cats_yolo_labeled/dog.9902.jpg', '39,46,452,427,1']
# ['dogs_cats_yolo_labeled/dog.9929.jpg', '21,73,436,398,1']
# ['dogs_cats_yolo_labeled/cat.9968.jpg', '14,15,427,261,0']
# ['dogs_cats_yolo_labeled/cat.9985.jpg', '7,10,413,303,0']
# ['dogs_cats_yolo_labeled/cat.9915.jpg', '26,26,490,297,0']
# ['dogs_cats_yolo_labeled/cat.9994.jpg', '73,2,366,297,0']
# ['dogs_cats_yolo_labeled/cat.9935.jpg', '173,23,440,239,0']
# ['dogs_cats_yolo_labeled/dog.9994.jpg', '127,60,364,268,1']
# ['dogs_cats_yolo_labeled/dog.9942.jpg', '65,118,268,418,1']
# ['dogs_cats_yolo_labeled/cat.9952.jpg', '43,3,332,373,0']
# ['dogs_cats_yolo_labeled/dog.9912.jpg', '38,24,411,371,1']
# ['dogs_cats_yolo_labeled/cat.9983.jpg', '159,62,298,149,0']
# labels.txt created.

# %%
# !ls -al labels.txt
# Out:
# -rw-r--r-- 1 root root 11736 Aug 25 08:32 labels.txt

# %%
# !head labels.txt
# Out:
# dogs_cats_yolo_labeled/cat.9943.jpg 156,27,323,215,0
# dogs_cats_yolo_labeled/dog.9980.jpg 29,40,459,432,1
# dogs_cats_yolo_labeled/dog.9960.jpg 66,14,383,395,1
# dogs_cats_yolo_labeled/cat.9926.jpg 16,25,219,452,0
# dogs_cats_yolo_labeled/dog.9964.jpg 60,33,431,248,1
# dogs_cats_yolo_labeled/dog.9936.jpg 66,41,259,487,1
# dogs_cats_yolo_labeled/cat.9925.jpg 16,45,217,178,0
# dogs_cats_yolo_labeled/cat.9950.jpg 42,1,164,196,0
# dogs_cats_yolo_labeled/dog.9961.jpg 12,8,154,276,1
# dogs_cats_yolo_labeled/dog.9974.jpg 62,14,215,370,1

# %%
# %%shell
# cd /content/keras-yolo3
# ls -al dogs_cats_yolo_labeled/cat.99.jpg
# ls -al dogs_cats_yolo_labeled/class_names.txt
# ls -al labels.txt
# ls -al yolov3.h5
# Out:
# -rw-r--r-- 1 root root 6638 Aug 24 01:43 dogs_cats_yolo_labeled/cat.99.jpg
# -rw-r--r-- 1 root root 8 Aug 24 23:59 dogs_cats_yolo_labeled/class_names.txt
# -rw-r--r-- 1 root root 11736 Aug 26 00:07 labels.txt
# -rw------- 1 root root 248686680 Aug 26 00:06 yolov3.h5

# %% [markdown]
# ## 학습 실행
#
# 학습에 필요한 파일은 4개이다.
#
# - 이미지 파일들 : dogs_cats_yolo_labeled/*.jpg
# - 클래스 이름 파일 : dogs_cats_yolo_labeled/class_names.txt
# - 레이블링 파일 : labels.txt
# - 기반 모델 파일 : yolov3.h5
#
#
# 그런데 2020/08/25 현재 이 파일 이름들은 train.py안에 하드코딩 되어있다.
# - 클래스 파일 : model_data/voc_classes.txt
# - 레이블링 파일 : train.txt
# - 기반 학습 모델 : model_data/yolo_weights.h5
#
# 하드 코딩된 바 데로 이름을 변경하고 실행한다.

# %%
# %%shell
# cd /content/keras-yolo3
# cp dogs_cats_yolo_labeled/class_names.txt model_data/voc_classes.txt
# cp labels.txt train.txt
# cp yolov3.h5 model_data/yolo_weights.h5

# %%
# !python3 train.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-08-25 08:38:15.750536: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-08-25 08:38:15.801083: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000140000 Hz
# 2020-08-25 08:38:15.801346: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1336bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-25 08:38:15.801382: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-25 08:38:15.807162: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-25 08:38:16.035306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 08:38:16.036042: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1336d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-25 08:38:16.036077: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-08-25 08:38:16.037360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 08:38:16.037961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-25 08:38:16.038286: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-25 08:38:16.293201: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-25 08:38:16.449107: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-08-25 08:38:16.473012: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-08-25 08:38:16.760313: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-08-25 08:38:16.787488: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-08-25 08:38:17.307920: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-25 08:38:17.308114: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 08:38:17.308754: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 08:38:17.309314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-08-25 08:38:17.311483: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-25 08:38:17.312591: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-25 08:38:17.312621: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-08-25 08:38:17.312631: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-08-25 08:38:17.314084: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 08:38:17.314638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 08:38:17.315143: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-08-25 08:38:17.315183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# Create YOLOv3 model with 9 anchors and 2 classes.
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_59 due to mismatch in shape ((1, 1, 1024, 21) vs (255, 1024, 1, 1)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_59 due to mismatch in shape ((21,) vs (255,)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_67 due to mismatch in shape ((1, 1, 512, 21) vs (255, 512, 1, 1)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_67 due to mismatch in shape ((21,) vs (255,)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_75 due to mismatch in shape ((1, 1, 256, 21) vs (255, 256, 1, 1)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_75 due to mismatch in shape ((21,) vs (255,)).
#   weight_values[i].shape))
# Load weights model_data/yolo_weights.h5.
# Freeze the first 249 layers of total 252 layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1521: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3080: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Train on 200 samples, val on 22 samples, with batch size 32.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/50
# 2020-08-25 08:38:41.898907: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] shape_optimizer failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2020-08-25 08:38:41.962854: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2020-08-25 08:38:42.318216: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] layout failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2020-08-25 08:38:42.760575: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] shape_optimizer failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2020-08-25 08:38:42.837773: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2020-08-25 08:38:44.729680: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-25 08:38:51.200221: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
#
# 6/6 [==============================] - 14s 2s/step - loss: 64.7023 - val_loss: 58.4796
# Epoch 30/50
# 6/6 [==============================] - 14s 2s/step - loss: 63.4352 - val_loss: 49.8009
# Epoch 31/50
# 6/6 [==============================] - 14s 2s/step - loss: 62.1619 - val_loss: 54.7270
# Epoch 32/50
# 6/6 [==============================] - 14s 2s/step - loss: 57.2708 - val_loss: 51.1087
# Epoch 33/50
# 6/6 [==============================] - 14s 2s/step - loss: 57.1477 - val_loss: 53.3398
# Epoch 34/50
# 6/6 [==============================] - 14s 2s/step - loss: 54.1516 - val_loss: 47.5965
# Epoch 35/50
# 6/6 [==============================] - 14s 2s/step - loss: 54.8452 - val_loss: 49.6048
# Epoch 36/50
# 6/6 [==============================] - 14s 2s/step - loss: 55.2582 - val_loss: 44.5971
# Epoch 37/50
# 6/6 [==============================] - 14s 2s/step - loss: 51.8804 - val_loss: 48.0608
# Epoch 38/50
# 6/6 [==============================] - 14s 2s/step - loss: 50.9288 - val_loss: 47.2077
# Epoch 39/50
# 6/6 [==============================] - 14s 2s/step - loss: 49.5536 - val_loss: 42.4541
# Epoch 40/50
# 6/6 [==============================] - 13s 2s/step - loss: 47.7563 - val_loss: 39.0884
# Epoch 41/50
# 6/6 [==============================] - 14s 2s/step - loss: 47.3659 - val_loss: 40.7009
# Epoch 42/50
# 6/6 [==============================] - 14s 2s/step - loss: 46.5001 - val_loss: 40.8206
# Epoch 43/50
# 6/6 [==============================] - 13s 2s/step - loss: 44.1509 - val_loss: 38.7368
# Epoch 44/50
# 6/6 [==============================] - 14s 2s/step - loss: 44.1144 - val_loss: 41.1728
# Epoch 45/50
# 6/6 [==============================] - 14s 2s/step - loss: 44.7134 - val_loss: 38.0738
# Epoch 46/50
# 6/6 [==============================] - 13s 2s/step - loss: 42.6507 - val_loss: 36.7770
# Epoch 47/50
# 6/6 [==============================] - 14s 2s/step - loss: 42.9041 - val_loss: 39.2941
# Epoch 48/50
# 6/6 [==============================] - 14s 2s/step - loss: 40.5351 - val_loss: 34.1343
# Epoch 49/50
# 6/6 [==============================] - 13s 2s/step - loss: 39.7304 - val_loss: 34.3025
# Epoch 50/50
# 6/6 [==============================] - 14s 2s/step - loss: 40.6860 - val_loss: 37.3207
# Unfreeze all of the layers.
# Train on 200 samples, val on 22 samples, with batch size 32.
# Epoch 51/100
# 2020-08-25 08:51:10.234571: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] shape_optimizer failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2020-08-25 08:51:10.735583: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2020-08-25 08:51:13.273886: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] layout failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2020-08-25 08:51:15.642482: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] shape_optimizer failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2020-08-25 08:51:15.999598: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2020-08-25 08:51:21.830062: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 289.69MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2020-08-25 08:51:31.835429: W tensorflow/core/common_runtime/bfc_allocator.cc:419] Allocator (GPU_0_bfc) ran out of memory trying to allocate 42.25MiB (rounded to 44302336).  Current allocation summary follows.
# 2020-08-25 08:51:31.835624: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (256): 	Total Chunks: 1237, Chunks in use: 1233. 309.2KiB allocated for chunks. 308.2KiB in use in bin. 32.8KiB client-requested in use in bin.
# 2020-08-25 08:51:31.835670: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (512): 	Total Chunks: 303, Chunks in use: 295. 151.8KiB allocated for chunks. 147.5KiB in use in bin. 147.5KiB client-requested in use in bin.
# 2020-08-25 08:51:31.835690: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (1024): 	Total Chunks: 459, Chunks in use: 450. 460.2KiB allocated for chunks. 450.8KiB in use in bin. 450.0KiB client-requested in use in bin.
# 2020-08-25 08:51:31.835706: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (2048): 	Total Chunks: 353, Chunks in use: 353. 718.0KiB allocated for chunks. 718.0KiB in use in bin. 717.0KiB client-requested in use in bin.
# 2020-08-25 08:51:31.835720: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (4096): 	Total Chunks: 148, Chunks in use: 147. 595.5KiB allocated for chunks. 591.0KiB in use in bin. 588.0KiB client-requested in use in bin.
# 2020-08-25 08:51:31.835745: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (8192): 	Total Chunks: 8, Chunks in use: 8. 64.0KiB allocated for chunks. 64.0KiB in use in bin. 64.0KiB client-requested in use in bin.
# 2020-08-25 08:51:31.835761: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (16384): 	Total Chunks: 13, Chunks in use: 12. 278.2KiB allocated for chunks. 247.0KiB in use in bin. 246.8KiB client-requested in use in bin.
# 2020-08-25 08:51:31.835776: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (32768): 	Total Chunks: 29, Chunks in use: 29. 1.14MiB allocated for chunks. 1.14MiB in use in bin. 1.14MiB client-requested in use in bin.
# 2020-08-25 08:51:31.835789: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (65536): 	Total Chunks: 30, Chunks in use: 29. 2.45MiB allocated for chunks. 2.33MiB in use in bin. 2.32MiB client-requested in use in bin.
# 2020-08-25 08:51:31.835806: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (131072): 	Total Chunks: 91, Chunks in use: 80. 12.52MiB allocated for chunks. 11.09MiB in use in bin. 10.99MiB client-requested in use in bin.
# 2020-08-25 08:51:31.835821: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (262144): 	Total Chunks: 27, Chunks in use: 25. 8.39MiB allocated for chunks. 7.82MiB in use in bin. 7.79MiB client-requested in use in bin.
# 2020-08-25 08:51:31.835855: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (524288): 	Total Chunks: 91, Chunks in use: 79. 49.37MiB allocated for chunks. 43.12MiB in use in bin. 42.97MiB client-requested in use in bin.
# 2020-08-25 08:51:31.835871: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (1048576): 	Total Chunks: 91, Chunks in use: 79. 105.66MiB allocated for chunks. 92.05MiB in use in bin. 91.91MiB client-requested in use in bin.
# 2020-08-25 08:51:31.835886: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (2097152): 	Total Chunks: 51, Chunks in use: 44. 102.00MiB allocated for chunks. 88.00MiB in use in bin. 88.00MiB client-requested in use in bin.
# 2020-08-25 08:51:31.835902: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (4194304): 	Total Chunks: 86, Chunks in use: 74. 395.31MiB allocated for chunks. 341.30MiB in use in bin. 335.43MiB client-requested in use in bin.
# 2020-08-25 08:51:31.835917: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (8388608): 	Total Chunks: 1, Chunks in use: 1. 8.03MiB allocated for chunks. 8.03MiB in use in bin. 4.50MiB client-requested in use in bin.
# 2020-08-25 08:51:31.835932: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (16777216): 	Total Chunks: 58, Chunks in use: 50. 1.05GiB allocated for chunks. 925.43MiB in use in bin. 900.00MiB client-requested in use in bin.
# 2020-08-25 08:51:31.835946: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (33554432): 	Total Chunks: 27, Chunks in use: 27. 1.13GiB allocated for chunks. 1.13GiB in use in bin. 1.13GiB client-requested in use in bin.
# 2020-08-25 08:51:31.835960: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin
I tensorflow/core/common_runtime/bfc_allocator.cc:917] 75 Chunks of size 1179648 totalling 84.38MiB
# 2020-08-25 08:51:33.544001: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 1817088 totalling 1.73MiB
# 2020-08-25 08:51:33.544011: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 3 Chunks of size 2076672 totalling 5.94MiB
# 2020-08-25 08:51:33.544021: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 44 Chunks of size 2097152 totalling 88.00MiB
# 2020-08-25 08:51:33.544032: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 70 Chunks of size 4718592 totalling 315.00MiB
# 2020-08-25 08:51:33.544042: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 5242880 totalling 5.00MiB
# 2020-08-25 08:51:33.544052: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 7268352 totalling 6.93MiB
# 2020-08-25 08:51:33.544062: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 7340032 totalling 7.00MiB
# 2020-08-25 08:51:33.544072: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 7731712 totalling 7.37MiB
# 2020-08-25 08:51:33.544082: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 8424960 totalling 8.03MiB
# 2020-08-25 08:51:33.544092: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 47 Chunks of size 18874368 totalling 846.00MiB
# 2020-08-25 08:51:33.544103: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 20971520 totalling 20.00MiB
# 2020-08-25 08:51:33.544114: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 29860096 totalling 28.48MiB
# 2020-08-25 08:51:33.544125: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 32462080 totalling 30.96MiB
# 2020-08-25 08:51:33.544718: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 26 Chunks of size 44302336 totalling 1.07GiB
# 2020-08-25 08:51:33.544751: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 66453504 totalling 63.38MiB
# 2020-08-25 08:51:33.544764: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 35 Chunks of size 88604672 totalling 2.89GiB
# 2020-08-25 08:51:33.544776: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 117561600 totalling 112.12MiB
# 2020-08-25 08:51:33.544787: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 13 Chunks of size 177209344 totalling 2.15GiB
# 2020-08-25 08:51:33.544798: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 180633600 totalling 172.27MiB
# 2020-08-25 08:51:33.544809: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 212324352 totalling 202.49MiB
# 2020-08-25 08:51:33.544820: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 249943552 totalling 238.36MiB
# 2020-08-25 08:51:33.544853: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 7 Chunks of size 354418688 totalling 2.31GiB
# 2020-08-25 08:51:33.544865: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 357834752 totalling 341.26MiB
# 2020-08-25 08:51:33.544876: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 3 Chunks of size 708837376 totalling 1.98GiB
# 2020-08-25 08:51:33.544887: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 712249344 totalling 679.25MiB
# 2020-08-25 08:51:33.544898: I tensorflow/core/common_runtime/bfc_allocator.cc:921] Sum Total of in-use chunks: 13.65GiB
# 2020-08-25 08:51:33.544909: I tensorflow/core/common_runtime/bfc_allocator.cc:923] total_region_allocated_bytes_: 14912198912 memory_limit_: 14912199066 available bytes: 154 curr_region_allocation_bytes_: 17179869184
# 2020-08-25 08:51:33.544927: I tensorflow/core/common_runtime/bfc_allocator.cc:929] Stats:
# Limit:                 14912199066
# InUse:                 14657944320
# MaxInUse:              14657966848
# NumAllocs:                 1092251
# MaxAllocSize:           2512412672
#
# 2020-08-25 08:51:33.545112: W tensorflow/core/common_runtime/bfc_allocator.cc:424] ****************************************************************************************************
# 2020-08-25 08:51:33.545172: W tensorflow/core/framework/op_kernel.cc:1651] OP_REQUIRES failed at fused_batch_norm_op.cc:703 : Resource exhausted: OOM when allocating tensor with shape[32,128,52,52] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# Traceback (most recent call last):
#   File "train.py", line 190, in <module>
#     _main()
#   File "train.py", line 84, in _main
#     callbacks=[logging, checkpoint, reduce_lr, early_stopping])
#   File "/usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/training.py", line 1418, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py", line 217, in fit_generator
#     class_weight=class_weight)
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/training.py", line 1217, in train_on_batch
#     outputs = self.train_function(ins)
#   File "/usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py", line 2715, in __call__
#     return self._call(inputs)
#   File "/usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py", line 2675, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py", line 1472, in __call__
#     run_metadata_ptr)
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted: OOM when allocating tensor with shape[32,128,52,52] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node batch_normalization_23/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[loss_1/add_74/_5299]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted: OOM when allocating tensor with shape[32,128,52,52] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node batch_normalization_23/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored.

# %% [markdown]
# ## train.py 사용 말고
#
# 다음은 train.py의 코드를 그대로 가져온 것이다.
#
# 이 경우 epcoh, annotion_path, clas_path, weight_path등의 변경해서 사용할 수 있다.

# %%
INIT_EPOCH = 5   # conv 레이어들을 고정하고 학습
MAIN_EPOCH = 5   # 이후 conv 레이어들까지 학습
BATCH_SIZE = 16
ANNOTATOIN_PATH = 'train.txt'
CLASS_PATH = 'model_data/voc_classes.txt'
WEIGHT_PATH = 'model_data/yolo_weights.h5'
ANCHORS_PATH = 'model_data/yolo_anchors.txt'

# %%
"""
Retrain the YOLO model for your own dataset.
"""

import numpy as np
import keras.backend as K
from keras.layers import Input, Lambda
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

from yolo3.model import preprocess_true_boxes, yolo_body, tiny_yolo_body, yolo_loss
from yolo3.utils import get_random_data


def _main():
    annotation_path = ANNOTATOIN_PATH
    log_dir = 'logs/000/'
    classes_path = CLASS_PATH
    anchors_path = ANCHORS_PATH
    class_names = get_classes(classes_path)
    num_classes = len(class_names)
    anchors = get_anchors(anchors_path)

    input_shape = (416,416) # multiple of 32, hw

    is_tiny_version = len(anchors)==6 # default setting
    if is_tiny_version:
        model = create_tiny_model(input_shape, anchors, num_classes,
            freeze_body=2, weights_path=WEIGHT_PATH)
    else:
        model = create_model(input_shape, anchors, num_classes,
            freeze_body=2, weights_path=WEIGHT_PATH) # make sure you know what you freeze

    logging = TensorBoard(log_dir=log_dir)
    checkpoint = ModelCheckpoint(log_dir + 'ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5',
        monitor='val_loss', save_weights_only=True, save_best_only=True, period=3)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)

    val_split = 0.1
    with open(annotation_path) as f:
        lines = f.readlines()
    np.random.seed(10101)
    np.random.shuffle(lines)
    np.random.seed(None)
    num_val = int(len(lines)*val_split)
    num_train = len(lines) - num_val

    # Train with frozen layers first, to get a stable loss.
    # Adjust num epochs to your dataset. This step is enough to obtain a not bad model.
    if True:
        model.compile(optimizer=Adam(lr=1e-3), loss={
            # use custom yolo_loss Lambda layer.
            'yolo_loss': lambda y_true, y_pred: y_pred})

        batch_size = BATCH_SIZE
        print('Train on {} samples, val on {} samples, with batch size {}.'.format(num_train, num_val, batch_size))
        model.fit_generator(data_generator_wrapper(lines[:num_train], batch_size, input_shape, anchors, num_classes),
                steps_per_epoch=max(1, num_train//batch_size),
                validation_data=data_generator_wrapper(lines[num_train:], batch_size, input_shape, anchors, num_classes),
                validation_steps=max(1, num_val//batch_size),
                epochs=INIT_EPOCH,
                initial_epoch=0,
                callbacks=[logging, checkpoint])
        model.save_weights(log_dir + 'trained_weights_stage_1.h5')

    # Unfreeze and continue training, to fine-tune.
    # Train longer if the result is not good.
    if True:
        for i in range(len(model.layers)):
            model.layers[i].trainable = True
        model.compile(optimizer=Adam(lr=1e-4), loss={'yolo_loss': lambda y_true, y_pred: y_pred}) # recompile to apply the change
        print('Unfreeze all of the layers.')

        batch_size = BATCH_SIZE # note that more GPU memory is required after unfreezing the body
        print('Train on {} samples, val on {} samples, with batch size {}.'.format(num_train, num_val, batch_size))
        model.fit_generator(data_generator_wrapper(lines[:num_train], batch_size, input_shape, anchors, num_classes),
            steps_per_epoch=max(1, num_train//batch_size),
            validation_data=data_generator_wrapper(lines[num_train:], batch_size, input_shape, anchors, num_classes),
            validation_steps=max(1, num_val//batch_size),
            epochs=MAIN_EPOCH,
            initial_epoch=50,
            callbacks=[logging, checkpoint, reduce_lr, early_stopping])
        model.save_weights(log_dir + 'trained_weights_final.h5')

    # Further training if needed.


def get_classes(classes_path):
    '''loads the classes'''
    with open(classes_path) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]
    return class_names

def get_anchors(anchors_path):
    '''loads the anchors from a file'''
    with open(anchors_path) as f:
        anchors = f.readline()
    anchors = [float(x) for x in anchors.split(',')]
    return np.array(anchors).reshape(-1, 2)


def create_model(input_shape, anchors, num_classes, load_pretrained=True, freeze_body=2,
            weights_path='model_data/yolo_weights.h5'):
    '''create the training model'''
    K.clear_session() # get a new session
    image_input = Input(shape=(None, None, 3))
    h, w = input_shape
    num_anchors = len(anchors)

    y_true = [Input(shape=(h//{0:32, 1:16, 2:8}[l], w//{0:32, 1:16, 2:8}[l], \
        num_anchors//3, num_classes+5)) for l in range(3)]

    model_body = yolo_body(image_input, num_anchors//3, num_classes)
    print('Create YOLOv3 model with {} anchors and {} classes.'.format(num_anchors, num_classes))

    if load_pretrained:
        model_body.load_weights(weights_path, by_name=True, skip_mismatch=True)
        print('Load weights {}.'.format(weights_path))
        if freeze_body in [1, 2]:
            # Freeze darknet53 body or freeze all but 3 output layers.
            num = (185, len(model_body.layers)-3)[freeze_body-1]
            for i in range(num): model_body.layers[i].trainable = False
            print('Freeze the first {} layers of total {} layers.'.format(num, len(model_body.layers)))

    model_loss = Lambda(yolo_loss, output_shape=(1,), name='yolo_loss',
        arguments={'anchors': anchors, 'num_classes': num_classes, 'ignore_thresh': 0.5})(
        [*model_body.output, *y_true])
    model = Model([model_body.input, *y_true], model_loss)

    return model

def create_tiny_model(input_shape, anchors, num_classes, load_pretrained=True, freeze_body=2,
            weights_path='model_data/tiny_yolo_weights.h5'):
    '''create the training model, for Tiny YOLOv3'''
    K.clear_session() # get a new session
    image_input = Input(shape=(None, None, 3))
    h, w = input_shape
    num_anchors = len(anchors)

    y_true = [Input(shape=(h//{0:32, 1:16}[l], w//{0:32, 1:16}[l], \
        num_anchors//2, num_classes+5)) for l in range(2)]

    model_body = tiny_yolo_body(image_input, num_anchors//2, num_classes)
    print('Create Tiny YOLOv3 model with {} anchors and {} classes.'.format(num_anchors, num_classes))

    if load_pretrained:
        model_body.load_weights(weights_path, by_name=True, skip_mismatch=True)
        print('Load weights {}.'.format(weights_path))
        if freeze_body in [1, 2]:
            # Freeze the darknet body or freeze all but 2 output layers.
            num = (20, len(model_body.layers)-2)[freeze_body-1]
            for i in range(num): model_body.layers[i].trainable = False
            print('Freeze the first {} layers of total {} layers.'.format(num, len(model_body.layers)))

    model_loss = Lambda(yolo_loss, output_shape=(1,), name='yolo_loss',
        arguments={'anchors': anchors, 'num_classes': num_classes, 'ignore_thresh': 0.7})(
        [*model_body.output, *y_true])
    model = Model([model_body.input, *y_true], model_loss)

    return model

def data_generator(annotation_lines, batch_size, input_shape, anchors, num_classes):
    '''data generator for fit_generator'''
    n = len(annotation_lines)
    i = 0
    while True:
        image_data = []
        box_data = []
        for b in range(batch_size):
            if i==0:
                np.random.shuffle(annotation_lines)
            image, box = get_random_data(annotation_lines[i], input_shape, random=True)
            image_data.append(image)
            box_data.append(box)
            i = (i+1) % n
        image_data = np.array(image_data)
        box_data = np.array(box_data)
        y_true = preprocess_true_boxes(box_data, input_shape, anchors, num_classes)
        yield [image_data, *y_true], np.zeros(batch_size)

def data_generator_wrapper(annotation_lines, batch_size, input_shape, anchors, num_classes):
    n = len(annotation_lines)
    if n==0 or batch_size<=0: return None
    return data_generator(annotation_lines, batch_size, input_shape, anchors, num_classes)


_main()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# Create YOLOv3 model with 9 anchors and 2 classes.
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_59 due to mismatch in shape ((1, 1, 1024, 21) vs (255, 1024, 1, 1)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_59 due to mismatch in shape ((21,) vs (255,)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_67 due to mismatch in shape ((1, 1, 512, 21) vs (255, 512, 1, 1)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_67 due to mismatch in shape ((21,) vs (255,)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_75 due to mismatch in shape ((1, 1, 256, 21) vs (255, 256, 1, 1)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_75 due to mismatch in shape ((21,) vs (255,)).
#   weight_values[i].shape))
# Load weights model_data/yolo_weights.h5.
# Freeze the first 249 layers of total 252 layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1521: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3080: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Train on 200 samples, val on 22 samples, with batch size 16.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/5
# 12/12 [==============================] - 25s 2s/step - loss: 4691.6460 - val_loss: 2134.6648
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:995: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/5
# 12/12 [==============================] - 12s 980ms/step - loss: 1233.9052 - val_loss: 734.3619
# Epoch 3/5
# 12/12 [==============================] - 13s 1s/step - loss: 493.4309 - val_loss: 307.2795
# Epoch 4/5
# 12/12 [==============================] - 5s 408ms/step - loss: 290.7304 - val_loss: 238.6727
# Epoch 5/5
# 12/12 [==============================] - 11s 947ms/step - loss: 208.4141 - val_loss: 213.3168
# Unfreeze all of the layers.
# Train on 200 samples, val on 22 samples, with batch size 16.

# %%
from IPython.display import display 
from PIL import Image
from yolo import YOLO

yolo = YOLO(model_path=WEIGHT_PATH, anchors_path=ANCHORS_PATH, classes_path=CLASS_PATH)

image = Image.open('dogs_cats_yolo_labeled/cat.99.jpg')
result_image = yolo.detect_image(image)

display(result_image)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-244f402660cb> in <module>()
#       3 from yolo import YOLO
#       4
# ----> 5 yolo = YOLO(model_path=WEIGHT_PATH, anchors_path=ANCHORS_PATH, classes_path=CLASS_PATH)
#       6
#       7 image = Image.open('dogs_cats_yolo_labeled/cat.99.jpg')
#
# /content/keras-yolo3/yolo.py in __init__(self, **kwargs)
#      43         self.anchors = self._get_anchors()
#      44         self.sess = K.get_session()
# ---> 45         self.boxes, self.scores, self.classes = self.generate()
#      46
#      47     def _get_class(self):
#
# /content/keras-yolo3/yolo.py in generate(self)
#      76             assert self.yolo_model.layers[-1].output_shape[-1] == \
#      77                 num_anchors/len(self.yolo_model.output) * (num_classes + 5), \
# ---> 78                 'Mismatch between model and given anchor and class sizes'
#      79
#      80         print('{} model, anchors, and classes loaded.'.format(model_path))
#
# AssertionError: Mismatch between model and given anchor and class sizes
